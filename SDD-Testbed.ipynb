# %%
import torch
import torchvision.models as models
import torch.nn as nn

# %%
nn.ModuleList(resnet50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-4d021a4bf620> in <module>()
# ----> 1 nn.ModuleList(resnet50)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/torch/nn/modules/container.py in __init__(self, modules)
#      95         super(ModuleList, self).__init__()
#      96         if modules is not None:
# ---> 97             self += modules
#      98
#      99     def __getitem__(self, idx):
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/torch/nn/modules/container.py in __iadd__(self, modules)
#     114
#     115     def __iadd__(self, modules):
# --> 116         return self.extend(modules)
#     117
#     118     def append(self, module):
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/torch/nn/modules/container.py in extend(self, modules)
#     133         if not isinstance(modules, list):
# ...

# %%
resnet50 = models.resnet50(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /home/z0m6ie/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:15<00:00, 6487816.37it/s]

# %%
resnet50
# Out:
# ResNet(
#   (conv1): Conv2d (3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d (64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
resnet50.parameters
# Out:
# <bound method Module.parameters of ResNet(
#   (conv1): Conv2d (3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d (64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
resnet50.layer4[0]
# Out:
# Bottleneck(
#   (conv1): Conv2d (1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#   (conv2): Conv2d (512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#   (conv3): Conv2d (512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#   (relu): ReLU(inplace)
#   (downsample): Sequential(
#     (0): Conv2d (1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True)
#   )
# )

# %%
resnet50.forward
# Out:
# <bound method ResNet.forward of ResNet(
#   (conv1): Conv2d (3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d (64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv2): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (conv3): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d (64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import glob
files = glob.glob('/home/z0m6ie/Documents/GitHub/**/*.txt', recursive=True)

# %%
files
# Out:
# ['/home/z0m6ie/Documents/GitHub/Machine_Learning_Projects/deep-Q-learning/Atari_DQN/Output.txt',
#  '/home/z0m6ie/Documents/GitHub/IPD_App/requirements.txt',
#  '/home/z0m6ie/Documents/GitHub/IPD_App/runtime.txt',
#  '/home/z0m6ie/Documents/GitHub/CarND_P5_Vehicle_Detection/Combined/READ.txt',
#  '/home/z0m6ie/Documents/GitHub/CarND_P5_Vehicle_Detection/output_images/save_output_here.txt',
#  '/home/z0m6ie/Documents/GitHub/CarND_P4_Advanced_Lane_Lines/output_images/save_output_here.txt',
#  '/home/z0m6ie/Documents/GitHub/Zombie_Code/AI_Course/8 Puzzle Solver/output.txt',
#  '/home/z0m6ie/Documents/GitHub/Zombie_Code/Web_Apps/CAPEX/requirements.txt',
#  '/home/z0m6ie/Documents/GitHub/App_Capex/requirements.txt',
#  '/home/z0m6ie/Documents/GitHub/App_Capex/runtime.txt']

# %%
import fileinput
outfilename = 'bigtxt.txt'
with open(outfilename, 'w') as fout, fileinput.input(files) as fin:
    for line in fin:
        fout.write(line)
